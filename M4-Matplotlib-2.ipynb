# %%
#Q1 Plot a Bar Graph of the data, taking the Year as the x-axis and the number of hurricanes occurring as the Y-axis.
import matplotlib.pyplot as plt, pandas

df = pandas.read_csv('F:\sreenu\Data Science\Python\Module-4 Dataset/Hurricanes.csv', delimiter=',')
print(df)
# Out:
#      Year  Hurricanes
# 0    1914           0
# 1    1915           5
# 2    1916          10
# 3    1917           2
# 4    1918           4
# 5    1919           2
# 6    1920           4
# 7    1921           5
# 8    1922           3
# 9    1923           4
# 10   1924           5
# 11   1925           1
# 12   1926           8
# 13   1927           4
# 14   1928           4
# 15   1929           3
# 16   1930           2
# 17   1931           3
# 18   1932           6
# 19   1933          11
# 20   1934           7
# 21   1935           5
# 22   1936           7
# 23   1937           4
# 24   1938           4
# 25   1939           3
# 26   1940           6
# 27   1941           4
# 28   1942           4
# 29   1943           5
# ..    ...         ...
# 71   1985           7
# 72   1986           4
# 73   1987           3
# 74   1988           5
# 75   1989           7
# 76   1990           8
# 77   1991           4
# 78   1992           4
# 79   1993           4
# ...

# %%
plt.bar(df["Year"], df["Hurricanes"])
plt.show()

# %%
#Q2 The dataset given, records data of city temperatures over the years’2014 and 2015. Plot the histogram of the 
#temperatures over this period for the cities of San Francisco and Moscow.

# %%
#Q2
import matplotlib.pyplot as plt, pandas

df = pandas.read_csv('F:\sreenu\Data Science\Python\Module-4 Dataset/CityTemps.csv', delimiter=',')

plt.hist([df["San Francisco"],df["Moscow"]])
plt.show()

# %%
#Q3 Create csv file from the data file available in LMS which goes by the name ‘M4_assign_dataset’and read this file into 
#a pandas data frame

# %%
#Q3
#Phase 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sales=pd.read_csv("F:\sreenu\Data Science\Python\Module-4 Dataset/sample-salesv2.csv",parse_dates=['date'])
print(sales.head())
# Out:
#    account_number                           name item_code category  quantity  \
# 0          296809                    Carroll PLC  QN-82852     Belt        13
# 1           98022              Heidenreich-Bosco  MJ-21460    Shoes        19
# 2          563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt        12
# 3           93356                  Waters-Walker  AS-93055    Shirt         5
# 4          659366                  Waelchi-Fahey  AS-93055    Shirt        18
#
#    unit price  net_price                date
# 0       44.48     578.24 2014-09-27 07:13:00
# 1       53.62    1018.78 2014-07-29 02:10:00
# 2       24.16     289.92 2014-01-03 10:51:00
# 3       82.68     413.40 2013-11-17 20:41:00
# 4       99.64    1793.52 2014-03-01 08:14:00

# %%
#phase 2
print(sales['unit price'].describe())
# Out:
# count    1000.000000
# mean       56.179630
# std        25.331939
# min        10.060000
# 25%        35.995000
# 50%        56.765000
# 75%        76.802500
# max        99.970000
# Name: unit price, dtype: float64

# %%
#phase 3
customers = sales[['name','net_price','date']]
customer_group = customers.groupby('name')
print(customer_group.size())
# Out:
# name
# Berge LLC                        52
# Carroll PLC                      57
# Cole-Eichmann                    51
# Davis, Kshlerin and Reilly       41
# Ernser, Cruickshank and Lind     47
# Gorczany-Hahn                    42
# Hamill-Hackett                   44
# Hegmann and Sons                 58
# Heidenreich-Bosco                40
# Huel-Haag                        43
# Kerluke, Reilly and Bechtelar    52
# Kihn, McClure and Denesik        58
# Kilback-Gerlach                  45
# Koelpin PLC                      53
# Kunze Inc                        54
# Kuphal, Zieme and Kub            52
# Senger, Upton and Breitenberg    59
# Volkman, Goyette and Lemke       48
# Waelchi-Fahey                    54
# Waters-Walker                    50
# dtype: int64

# %%
#Phase 4
sales_totals = customer_group.sum()
#sales_totals.sort(columns='ext price').head()
my_plot = sales_totals.plot(kind='bar')
plt.show()

# %%
#Q4 Let the x axis data points and y axis data points are
#Answer –4.1
#import matplotlib libary
import pandas as pd
import matplotlib.pyplot as plt
#define some data
x = [1,2,3,4]
y = [20, 21, 20.5, 20.8]
#plot data
plt.plot(x, y)
#show plot
plt.show()

# %%
#Answer – 4.2 Configure the line and markers in simple plot

#import matplotlib libary
import matplotlib.pyplot as plt

#define some data
x = [1,2,3,4]
y = [20, 21, 20.5, 20.8]

#plot data
plt.plot(x, y, linestyle="dashed", marker="o", color="green")

#show plot
plt.show()

# %%
#Answer – 4.3 configure the axes

#import matplotlib libary
import matplotlib.pyplot as plt

#define some data
x = [1,2,3,4]
y = [20, 21, 20.5, 20.8]

#plot data
plt.plot(x, y, linestyle="dashed", marker="o", color="green")

#configure  X axes
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])

#configure  Y axes
plt.ylim(19.8,21.2)
plt.yticks([20, 21, 20.5, 20.8])

#show plot
plt.show()

# %%
#Answer – 4.4 Give title of Graph & labels of x axis and y axis

#import matplotlib libary
import matplotlib.pyplot as plt

#define some data
x = [1,2,3,4]
y = [20, 21, 20.5, 20.8]

#plot data
plt.plot(x, y, linestyle="dashed", marker="o", color="green")

#configure  X axes
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])

#configure  Y axes
plt.ylim(19.8,21.2)
plt.yticks([20, 21, 20.5, 20.8])

#labels
plt.xlabel("this is X")
plt.ylabel("this is Y")

#title
plt.title("Simple plot")

#show plot
plt.show()

# %%
#Answer – 4.5 Give error bar if  y_error = [0.12, 0.13, 0.2, 0.1]

#import matplotlib libary
import matplotlib.pyplot as plt

#define some data
x = [1,2,3,4]
y = [20, 21, 20.5, 20.8]

#error data
y_error = [0.12, 0.13, 0.2, 0.1]

#plot data
plt.plot(x, y, linestyle="dashed", marker="o", color="green")

#plot only errorbars
plt.errorbar(x, y, yerr=y_error, linestyle="None", marker="None", color="green")

#configure  X axes
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])

#configure  Y axes
plt.ylim(19.8,21.2)
plt.yticks([20, 21, 20.5, 20.8])

#labels
plt.xlabel("this is X")
plt.ylabel("this is Y")

#title
plt.title("Simple plot")

#show plot
plt.show()

# %%
#Answer – 4.6 define width, height as figsize=(4,5) DPI and adjust plot dpi=100
#import matplotlib libary
import matplotlib.pyplot as plt

#define plot size in inches (width, height) & resolution(DPI)
fig = plt.figure(figsize=(4, 5), dpi=100)

#define some data
x = [1,2,3,4]
y = [20, 21, 20.5, 20.8]

#error data
y_error = [0.12, 0.13, 0.2, 0.1]

#plot data
plt.plot(x, y, linestyle="dashed", marker="o", color="green")

#plot only errorbars
plt.errorbar(x, y, yerr=y_error, linestyle="None", marker="None", color="green")

#configure  X axes
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])

#configure  Y axes
plt.ylim(19.8,21.2)
plt.yticks([20, 21, 20.5, 20.8])

#labels
plt.xlabel("this is X")
plt.ylabel("this is Y")

#title
plt.title("Simple plot")

#adjust plot
plt.subplots_adjust(left=0.18)

#show plot
plt.show()

# %%
#Answer – 4.7 Give a font size of 14

#import matplotlib libary
import matplotlib.pyplot as plt

#define plot size in inches (width, height) & resolution(DPI)
fig = plt.figure(figsize=(4, 5), dpi=100)

#define font size
plt.rc("font", size=14)

#define some data
x = [1,2,3,4]
y = [20, 21, 20.5, 20.8]

#error data
y_error = [0.12, 0.13, 0.2, 0.1]

#plot data
plt.plot(x, y, linestyle="dashed", marker="o", color="green")

#plot only errorbars
plt.errorbar(x, y, yerr=y_error, linestyle="None", marker="None", color="green")

#configure  X axes
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])

#configure  Y axes
plt.ylim(19.8,21.2)
plt.yticks([20, 21, 20.5, 20.8])

#labels
plt.xlabel("this is X")
plt.ylabel("this is Y")

#title
plt.title("Simple plot")

#adjust plot
plt.subplots_adjust(left=0.19)

#show plot
plt.show()

# %%
#Answer 4.8 Draw a scatter graph of any 50 random values of x and y axis
import numpy as np
import matplotlib.pyplot as plt
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
#Answer 4.9 Create a dataframe from following data

raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
        'female': [0, 1, 1, 0, 1],
        'age': [42, 52, 36, 24, 73],
        'preTestScore': [4, 24, 31, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'female', 'preTestScore', 'postTestScore'])
print(df.head(3))
# Draw a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
plt.scatter(df.preTestScore, df.postTestScore, s=df.age)
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57

# %%
#Answer 4.10 Draw a Scatterplot from the data in question 9 of preTestScore and postTestScore with the size = 300 and 
#the color determined by sex

plt.scatter(df.preTestScore, df.postTestScore, s=300, c=df.female)
